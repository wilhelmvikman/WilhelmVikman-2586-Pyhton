# %% [markdown]
# # Assignment 1
#
# This notebook contains the solutions for Assignment 1 in Python Programming for Business Intelligence.

# %% [markdown]
# ## Task 1
#
# (Write a short description of the task here)

# %%
print("Hello, world!")
# Out:
# Hello, world!
